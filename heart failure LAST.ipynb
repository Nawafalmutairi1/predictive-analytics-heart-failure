# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv("heart_NEW.csv")

df.sample(20)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 739   54   M           NAP        125          273          0        LVH
# 423   60   M           NAP        180            0          0         ST
# 477   61   M           ASY        110            0          1     Normal
# 224   55   M           ATA        120          256          1     Normal
# 172   53   M           ATA        140          320          0     Normal
# 470   53   M           ASY        126            0          0     Normal
# 361   47   M           ASY        160            0          0     Normal
# 533   63   M           ASY        110          252          0         ST
# 842   43   F           ASY        132          341          1        LVH
# 595   60   M           ASY        130          186          1        LVH
# 375   73   F           NAP        160            0          0         ST
# 786   69   M           NAP        140          254          0        LVH
# 758   51   M            TA        125          213          0        LVH
# 933   82   F           ATA        140          239          0     Normal
# 403   52   M           ASY        135            0          1     Normal
# 242   55   M           ATA        160          292          1     Normal
# 882   56   F           ATA        140          294          0        LVH
# 128   54   F           ATA        120          230          1     Normal
# 149   54   M           ASY        130          603          1     Normal
# 376   47   M           NAP        155            0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 739    152              N      0.5     Down             0
# 423    140              Y      1.5     Flat             0
# 477    108              Y      2.0     Down             1
# 224    137              N      0.0       Up             0
# 172    162              N      0.0       Up             0
# 470    106              N      0.0     Flat             1
# 361    124              Y      0.0     Flat             1
# 533    140              Y      2.0     Flat             1
# 842    136              Y      3.0     Flat             1
# 595    140              Y      0.5     Flat             1
# 375    121              N      0.0       Up             1
# 786    146              N      2.0     Flat             1
# 758    125              Y      1.4       Up             0
# 933    151              N      1.8       Up             0
# 403    128              Y      2.0     Flat             1
# 242    143              Y      2.0     Flat             1
# 882    153              N      1.3     Flat             0
# 128    140              N      0.0       Up             0
# 149    125              Y      1.0     Flat             1
# 376    118              Y      1.0     Flat             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             999 non-null    int64
#  1   Sex             999 non-null    object
#  2   ChestPainType   999 non-null    object
#  3   RestingBP       999 non-null    int64
#  4   Cholesterol     999 non-null    int64
#  5   FastingBS       999 non-null    int64
#  6   RestingECG      999 non-null    object
#  7   MaxHR           999 non-null    int64
#  8   ExerciseAngina  999 non-null    object
#  9   Oldpeak         999 non-null    float64
#  10  ST_Slope        999 non-null    object
#  11  HeartDisease    999 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 93.8+ KB

# %%
names = ['Resting BP', 'Chest Pain Type', 'Cholesterol', 'Exercise Angina']
size = [20,20,20,20]
 
my_circle = plt.Circle( (0,0), 0.7, color='white')

plt.pie(size, labels=names, colors=['red','green','blue','skyblue'])
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.savefig('All.png',dpi=150)
plt.show()

# %%
sns.heatmap(df.corr());

# %%
sns.histplot(df['Cholesterol'], kde=False,bins=20, stat='frequency');
plt.savefig('ch.png',dpi=150)

# %%
df.sample(20)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 543   70   M           ASY        170          192          0         ST
# 435   60   M           ASY        152            0          0         ST
# 868   51   M           NAP        110          175          0     Normal
# 112   47   M           ASY        140          276          1     Normal
# 185   58   M           NAP        160          211          1         ST
# 345   69   M           ASY        135            0          0     Normal
# 54    52   F           ASY        130          180          0     Normal
# 458   61   M           ASY        134            0          1         ST
# 105   57   M           ATA        140          260          1     Normal
# 597   55   M           NAP        133          185          0         ST
# 937   48   M           ATA        125          258          0        LVH
# 873   64   M           NAP        140          335          0     Normal
# 364   56   M           NAP        120            0          0     Normal
# 962   60   M           ASY        132          341          1        LVH
# 749   54   M           NAP        150          232          0        LVH
# 44    43   M           ASY        120          175          0     Normal
# 697   58   M           ASY        150          270          0        LVH
# 249   49   M           ASY        130          341          0     Normal
# 231   40   M           NAP        130          281          0     Normal
# 376   47   M           NAP        155            0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 543    129              Y      3.0     Down             1
# 435    118              Y      0.0       Up             0
# 868    123              N      0.6       Up             0
# 112    125              Y      0.0       Up             0
# 185     92              N      0.0     Flat             1
# 345    130              N      0.0     Flat             1
# 54     140              Y      1.5     Flat             0
# 458     86              N      1.5     Flat             1
# 105    140              N      0.0       Up             0
# 597    136              N      0.2       Up             0
# 937    141              Y      2.8     Flat             1
# 873    158              N      0.0       Up             1
# 364     97              N      0.0     Flat             0
# 962    136              Y      3.0     Flat             1
# 749    165              N      1.6       Up             0
# 44     120              Y      1.0     Flat             1
# 697    111              Y      0.8       Up             1
# 249    120              Y      1.0     Flat             1
# 231    167              N      0.0       Up             0
# 376    118              Y      1.0     Flat             1

# %%
df['Cholesterol'].describe()
# Out:
# count    999.000000
# mean     203.497497
# std      106.915273
# min        0.000000
# 25%      179.500000
# 50%      225.000000
# 75%      269.000000
# max      603.000000
# Name: Cholesterol, dtype: float64

# %%
df.Cholesterol.mean()
# Out:
# 203.4974974974975

# %%
 df['Cholesterol'] = df['Cholesterol'].replace(0, 203.4974974974975)

# %%
sns.histplot(df['Cholesterol'], kde=False,bins=20, stat='frequency');
plt.savefig('chnew.png',dpi=150)

# %%
conditions = [
    (df['Cholesterol'] >= 0) & (df['Cholesterol']<= 99),
    (df['Cholesterol'] >= 100) & (df['Cholesterol']<= 129),
    (df['Cholesterol'] >= 130) & (df['Cholesterol'] <= 159),
    (df['Cholesterol'] >= 160 ) & (df['Cholesterol'] <= 189),
    (df['Cholesterol'] >= 190 ) & (df['Cholesterol'] <= 650),
    ]

values = ['under normal','normal', 'above normal', 'high', 'very high']

df['Cholesterol_type'] = np.select(conditions, values)

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140        289.0          0     Normal    172
# 1   49   F           NAP        160        180.0          0     Normal    156
# 2   37   M           ATA        130        283.0          0         ST     98
# 3   48   F           ASY        138        214.0          0     Normal    108
# 4   54   M           NAP        150        195.0          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease Cholesterol_type
# 0              N      0.0       Up             0        very high
# 1              N      1.0     Flat             1             high
# 2              N      0.0       Up             0        very high
# 3              Y      1.5     Flat             1        very high
# 4              N      0.0       Up             0        very high

# %%
df.describe(include="all")
# Out:
#                Age  Sex ChestPainType   RestingBP  Cholesterol   FastingBS  \
# count   999.000000  999           999  999.000000   999.000000  999.000000
# unique         NaN    2             4         NaN          NaN         NaN
# top            NaN    M           ASY         NaN          NaN         NaN
# freq           NaN  753           526         NaN          NaN         NaN
# mean     54.402402  NaN           NaN  132.287287   238.534104    0.225225
# std      10.277816  NaN           NaN   18.347146    55.363127    0.417940
# min      28.000000  NaN           NaN    0.000000    85.000000    0.000000
# 25%      48.000000  NaN           NaN  120.000000   203.497497    0.000000
# 50%      55.000000  NaN           NaN  130.000000   225.000000    0.000000
# 75%      61.000000  NaN           NaN  140.000000   269.000000    0.000000
# max      95.000000  NaN           NaN  200.000000   603.000000    1.000000
#
#        RestingECG       MaxHR ExerciseAngina     Oldpeak ST_Slope  \
# count         999  999.000000            999  999.000000      999
# unique          3         NaN              2         NaN        3
# top        Normal         NaN              N         NaN     Flat
# freq          591         NaN            604         NaN      496
# mean          NaN  138.104104            NaN    0.910711      NaN
# std           NaN   25.474911            NaN    1.076659      NaN
# min           NaN   60.000000            NaN   -2.600000      NaN
# 25%           NaN  120.000000            NaN    0.000000      NaN
# 50%           NaN  140.000000            NaN    0.600000      NaN
# 75%           NaN  158.000000            NaN    1.500000      NaN
# max           NaN  202.000000            NaN    6.200000      NaN
#
#         HeartDisease Cholesterol_type
# count     999.000000              999
# unique           NaN                5
# top              NaN        very high
# freq             NaN              886
# mean        0.542543              NaN
# std         0.498436              NaN
# min         0.000000              NaN
# 25%         0.000000              NaN
# 50%         1.000000              NaN
# 75%         1.000000              NaN
# max         1.000000              NaN

# %%
mask_ChestPainType_HeartDisease = (df.ChestPainType == 'ATA') & (df.HeartDisease == 1) 

df[mask_ChestPainType_HeartDisease].shape[0]
# Out:
# 37

# %%
mask_ChestPainType_HeartDisease = (df.ChestPainType == 'NAP') & (df.HeartDisease == 1) 

df[mask_ChestPainType_HeartDisease].shape[0]
# Out:
# 79

# %%
mask_ChestPainType_HeartDisease = (df.ChestPainType == 'ASY') & (df.HeartDisease == 1) 

df[mask_ChestPainType_HeartDisease].shape[0]
# Out:
# 405

# %%
mask_ChestPainType_HeartDisease = (df.ChestPainType == 'TA') & (df.HeartDisease == 1) 

df[mask_ChestPainType_HeartDisease].shape[0]
# Out:
# 21

# %%
mask_Cholesterol_HeartDisease = (df.Cholesterol >= 160) & (df.HeartDisease >= 1) 

df[mask_Cholesterol_HeartDisease].shape[0]
# Out:
# 529

# %%
mask_Cholesterol_HeartDisease = (df.Cholesterol >= 190) & (df.HeartDisease >= 1) 

df[mask_Cholesterol_HeartDisease].shape[0]
# Out:
# 492

# %%
mask_ExerciseAngina_HeartDisease = (df.ExerciseAngina == 'Y') & (df.HeartDisease >= 1) 

df[mask_ExerciseAngina_HeartDisease].shape[0]
# Out:
# 337

# %%
mask_Sex_HeartDisease = (df.Sex == 'M') & (df.HeartDisease == 1) 

df[mask_Sex_HeartDisease].shape[0]
# Out:
# 469

# %%
mask_Age_HeartDisease = (df.Age >= 54) & (df.HeartDisease >= 1) 

df[mask_Age_HeartDisease].shape[0]
# Out:
# 363

# %%
mask_RestingBP_HeartDisease = (df.RestingBP >= 140) & (df.HeartDisease >= 1) 

df[mask_Cholesterol_HeartDisease].shape[0]
# Out:
# 492

# %%
type_counts = df['Sex'].value_counts()
df1 = pd.DataFrame({'Sex': type_counts})
df1.plot.pie(y='Sex', figsize=(6,20), autopct='%1.1f%%')
plt.yticks(rotation=90)
plt.savefig('Sex.png',dpi=150)

# %%
sns.histplot(df['Cholesterol_type'], kde=False,bins=20, stat='frequency');

# %%
type_counts = df['HeartDisease'].value_counts()
df1 = pd.DataFrame({'HeartDisease': type_counts})
df1.plot.pie(y='HeartDisease', figsize=(5,5), autopct='%1.1f%%');

# %%
df.groupby('Sex').mean()
# Out:
#            Age   RestingBP  Cholesterol  FastingBS       MaxHR   Oldpeak  \
# Sex
# F    55.495935  131.825203    254.96127   0.142276  147.219512  0.733333
# M    54.045153  132.438247    233.16746   0.252324  135.126162  0.968659
#
#      HeartDisease
# Sex
# F        0.296748
# M        0.622842

# %%
#Age - HeartDisease
print('Age - HeartDisease')
Age_df = pd.DataFrame(df['HeartDisease'].groupby(df['Age']).count())
plt.title('Age-HeartDisease')
plt.bar(Age_df.index, Age_df['HeartDisease'])
plt.xlabel('Age')
plt.ylabel('Number of patient Heart Disease')
#plt.show()
plt.savefig('Age-HeartDisease.png',dpi=150)
print()
# Out:
# Age - HeartDisease

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x=df["Cholesterol_type"])
